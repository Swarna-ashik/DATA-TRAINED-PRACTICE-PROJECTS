# %% [markdown]
# Problem Statement::
#
# Predict the salary if the employee using the features provided in the data.

# %%
import pandas as pd

# %%
df=pd.read_csv('salaryofemp.csv')
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
#above the columns we have obsorve

# %%
df.count()
# Out:
# rank             397
# discipline       397
# yrs.since.phd    397
# yrs.service      397
# sex              397
# salary           397
# dtype: int64

# %%
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Histogram

# %%
plt.hist(df['salary'],bins=10)
plt.title('HISTOGRAM')
plt.show()

# %% [markdown]
# The above histogram we have obsorve the more salary earning between 75000 to 100000

# %%
plt.hist(df['yrs.service'])
plt.title('HISTOGRAM')
plt.show()

# %% [markdown]
# more in between 5 to 10 years and lest experienc should be 55- 60 yrs. of service

# %%
plt.hist(df['rank'])
plt.title('HISTOGRAM')
plt.show()

# %% [markdown]
# Above the should be assprof and assocprof are less as compared to prof

# %%
plt.hist(df['discipline'],bins=10)
plt.title('HISTOGRAM')
plt.show()

# %% [markdown]
# In the decipline we had obsorve only variables (A, B ). B is heighest as compare to A

# %%
plt.hist(df['salary'],bins=10)
plt.title('HISTOGRAM')
plt.show()

# %%
#now 
import pandas as pd
import seaborn as sns

# %% [markdown]
# # SCATTERPLOT

# %%
sns.scatterplot(x='rank',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %% [markdown]
# the professor mostly up to two lakhs
#
# and the assis rank should be 100000
#
# the associative rank chould be 125000

# %%
sns.scatterplot(x='discipline',y='salary',data=df)
plt.title('Scatter Plot-1')
# Out:
# Text(0.5, 1.0, 'Scatter Plot-1')

# %% [markdown]
# From B is more acurate data we obsorve up to 2 lakh in

# %% [markdown]
# # Violin Plot

# %%
import warnings
sns.violinplot('salary',data=df)
plt.title('VIOLINPLOT-1')

warnings.filterwarnings('ignore')

# %% [markdown]
# In the volin plot most salaried members obsorved in 1 lakh

# %% [markdown]
# # work with seaborn library

# %% [raw]
# #(seaborn)sns contains
# stripplot
# swarmplot
# countplot
# roughplot # there are somany plots inside the seabornplot

# %%
import pandas as pd
import seaborn as sns
semp=pd.read_csv('salaryofemp.csv')
print(semp)
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %% [markdown]
# # Stripplot

# %%
ax=sns.stripplot(x='rank',y='salary',data=semp)
plt.title('Graph')
plt.show()

# %%
ax=sns.stripplot(x='yrs.since.phd',y='salary',data=semp)
plt.title('Graph')
plt.show()

# %%
ax=sns.stripplot(x='yrs.service',y='salary',data=semp)
plt.title('Graph')
plt.show()

# %%
ax=sns.stripplot(x='sex',y='salary',data=semp)
plt.title('Graph')
plt.show()

# %% [markdown]
# # Swarmplot

# %%
ax=sns.swarmplot(x='rank',y='salary', data=semp)
plt.title('Graph')
plt.show()

# %%
ax=sns.swarmplot(x='yrs.since.phd',y='salary', data=semp)
plt.title('Graph')
plt.show()

# %%
ax=sns.swarmplot(x='yrs.service',y='salary', data=semp)
plt.title('Graph')
plt.show()

# %%
ax=sns.swarmplot(x='sex',y='salary', data=semp)
plt.title('Graph')
plt.show()

# %%
semp['rank'].value_counts()
# Out:
# Prof         266
# AsstProf      67
# AssocProf     64
# Name: rank, dtype: int64

# %%
semp['yrs.service'].value_counts()
# Out:
# 3     22
# 19    19
# 7     18
# 8     18
# 23    16
# 18    15
# 2     15
# 9     15
# 11    14
# 4     13
# 1     13
# 0     11
# 27    11
# 6     11
# 10    11
# 20    10
# 31    10
# 30     9
# 15     9
# 28     9
# 16     8
# 14     8
# 22     8
# 38     8
# 5      8
# 25     8
# 26     7
# 17     6
# 36     6
# 21     6
# 40     5
# 35     5
# 12     5
# 39     4
# 45     4
# 33     4
# 43     4
# 37     4
# 49     3
# 44     3
# 24     2
# 34     2
# 41     1
# 32     1
# 13     1
# 46     1
# 48     1
# 29     1
# 51     1
# 53     1
# 57     1
# 60     1
# Name: yrs.service, dtype: int64

# %% [markdown]
# # countplot

# %%
sns.countplot(semp['rank'])
# Out:
# <AxesSubplot:xlabel='rank', ylabel='count'>

# %%
sns.countplot(semp['salary'])
plt.title('countplot')
# Out:
# Text(0.5, 1.0, 'countplot')

# %%
sns.countplot(semp['yrs.service'],data=semp)
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='count'>

# %%
sns.countplot(semp['yrs.since.phd'])
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='count'>

# %%
sns.countplot(semp['discipline'])
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='count'>

# %% [markdown]
# # Category plot

# %%
# shortely we will call this as catplot

# %%
#set up a category plot
g=sns.catplot(x='rank',y='salary',hue='sex',data=semp,kind='bar')
#show plot
plt.show()

# %%
#set up a category plot
g=sns.catplot(x='rank',y='salary',hue='sex',data=semp,kind='violin')
#showplot
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# # Distribution plot

# %% [raw]
# displot:
# histplot :
# joinplot :
# violenplot :
# rugplot :

# %% [markdown]
# # displot:

# %%
sns.violinplot(x='salary',data=semp)
#showing the plot
plt.show()

# %%
sns.violinplot(x='yrs.service',data=semp)

plt.show()

# %%
sns.violinplot(x='yrs.since.phd',data=semp)

plt.show()

# %%
sns.kdeplot(semp['salary'])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %% [markdown]
# # JOINTPLOT

# %%
sns.jointplot(data=semp,x='rank',y='salary')

# %%
#sns.rugplot?

# %%
sns.rugplot(data=semp,x='salary')
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
sns.boxplot(x='rank',y='salary',data=semp)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.displot(data=semp,kind='ecdf',x='salary',col='sex')
